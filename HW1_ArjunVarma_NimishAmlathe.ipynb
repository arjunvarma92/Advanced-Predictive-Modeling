# %% [markdown]
# # <p style="text-align: center;">MIS 382N: Advanced Predictive Modeling</p>
# # <p style="text-align: center;">Assignment 1</p>
# ## <p style="text-align: center;">Total points: 80</p>
# ## <p style="text-align: center;">Due: Wed, September 14</p>

# %% [markdown]
# ### Submitted by: Arjun Varma, Nimish Amlathe

# %% [markdown]
# # Question 1: Applications of machine learning (10 pts)
#
# The article "Of Prediction and Policy", posted on Canvas under Modules --> Additional Resources, mentions several applications of machine learning. Pick any one of the works mentioned in this short article and:
#
# 1. (2 pts) Find at least one technical article that describes the work and provide the  citation(s). Very easy to do by Googling the names/institutions.
# 2. (4pts) In a few sentences describe the methodology/approach that was used.
# 3. (2 pts) Summarize in a couple of sentences what you liked about this work, and
# 4. (2 pts) Also summarize in a couple of sentences any concerns you may have about the work or its  application to societal problems.
#
#
# ## Answer

# %% [markdown]
# ### 1. Identifying Police Officers at Risk of Adverse Events
#
# Citations: https://dssg.uchicago.edu/wp-content/uploads/2016/04/identifying-police-officers-3.pdf
#
#
#
# ### 2. Method and Approach :
#
# The researchers worked with the Charlotte-Mecklenburg Police Department (CMPD) to develop a machine learning model to predict which oﬃcers were at risk for an adverse event.
#
# The data for this work included almost all employee information and event records collected by CMPD to manage its day-to-day operations. The data included Internal Affairs data, Dispatch Data, criminal complaints, Citations, Arrests, Employee records, Training etc. Using this data to generate features for the model, at the oﬃcer level, behavioural features were generated by aggregating the record of incidents by each oﬃcer, establishing a behavioural history.
#
# Timeseries features were generated from raw event counts (e.g. a sudden increase in the number of arrests in the six-month period prior to the point of analysis) to capture sudden changes in behaviour. The model was validated using temporal cross validation.
#
# A variety of model types were tried, including AdaBoost, Random Forests, Logistic Regression, and Support Vector Machines. Random searches over a standard hyper parameter space using 3-fold cross-validation were used to tune each model.
#
# The Results showed that at the oﬃcer-level, about ∼ 8−9% of oﬃcers will end up having an adverse event of some type in a one year period. The best binary classiﬁcation model to predict these events was a Random Forest with 50 estimators.
#
#
# ### 3. What I liked :
#
# This research work is at the intersection of data science, social science and the practice of policing. The Work highlighted the features related to oﬃcer characteristics, situational factors, and neighbourhood factors that are predictive of adverse events. The model was robust with direction of feature’s effect inferred using Monte Carlo Simulation.
#
# ### 4. What I don’t Like :
#
#
# The best performance was given by a non-parametric model, Random Forest. However, its interpretation is very difficult.The correctness for the data is questionable since  the data was entered into CMPD system by the oﬃcers themselves, often in the midst of busy shifts or retroactively after their shifts have ended. In addition, Times and locations are often approximate, and these types of events often fail to be properly linked to an associated dispatch call, which limits what other information they can be linked to.

# %% [markdown]
# # Question 2: Maximum likelihood estimate (10 pts)
#
# Consider the following univariate probability distribution
# $$p(x|a,b) = \frac{x^{a-1}}{\Gamma(a)b^a}exp(-\frac{x}{b}),$$ for $x \geq 0$ and $a,b > 0.  ~~ \Gamma(a)$ is a normalization term.
#
# You are given N i.i.d. data points drawn from this distribution. Derive the MLE estimate for $b$, in terms of $x_1, x_2, \ldots x_N$ and $a$.
#
# ## Answer

# %% [markdown]
# #### Log Likelihood Maximization ###
#
# $Probability(likelihood) = \prod_{i=1}^Np(x_i|a,b)$
#
# $Log- likelihood =  	\sum_{i=1}^N\ln p(x_i|a,b)$
#
# $LL = \sum_{i=1}^N\ln\frac{x_i^{a-1}}{\Gamma(a)b^a}exp(-\frac{x_i}{b})$
#
# $LL = \sum_{i=1}^N(\ln {x_i^{a-1}} -ln {\Gamma(a)b^a} -\frac{x_i}{b}) $
#
# $LL = \sum_{i=1}^N(\ln {x_i^{a-1}} -ln \Gamma(a)-a ln b -\frac{x_i}{b}) $
#
# $LL = (a-1)(\sum_{i=1}^N\ln {x_i}) - N ln \Gamma(a)-N a\ln b -\frac{\sum_{i=1}^N{x_i}}{b}) $
#
# $\frac{\partial LL}{\partial b}= 0-0-\frac{N a}{b}+ \frac{\sum_{i=1}^N{x_i}}{b^2}$
#
# To find Maximum Likelihood, set derivative to 0 -> $\frac{\partial LL}{\partial b} =0$
#
# $ {b^2}$ cannot be 0,so
#
# $(\sum_{i=1}^N{x_i}) - Nab =0 $
#
# $ b = \frac{\sum_{i=1}^N{x_i}}{N a}$
#
# ##### Checking to see if double derivative is < 0 #####
#
# $\frac{\partial^2LL}{\partial b^2}= (-2) \frac{\sum_{i=1}^N{x_i}}{b^3} + \frac{N a}{b^2} $
#
# Substituting
# $ b = \frac{\sum_{i=1}^N{x_i}}{N a}$
#
# $\frac{\partial^2LL}{\partial b^2}= \frac{N^2 a^2 (1-2Na)}{(\sum_{i=1}^N{x_i})^2}$
# ###### The quantity (1-2Na) is less than 0. The second derivative will be negative thereby maximising likelihood at $b = \frac{\sum_{i=1}^N{x_i}}{N a}$ ######

# %% [markdown]
# # Question 3: Conditional Distributions (10 pts)
#
# The joint pdf of two random  variables $X_1$ and $X_2$ is  constant (i.e., the joint distribution is uniform) within the area shown below, and zero outside of it. Given this joint distribution, obtain  the following two univariate distributions from it. It is not necessary to write the equations, if the distributions can be plotted / described in full detail.
#
# a. (6 pts) The marginal distribution of $X_1$, $p_{X_1}(x_1)$
#
# b. (4 pts) The conditional distribution $p_{X_2|X_1}(x_2 \,|\, x_1 = 0.5)$
#
# <img src="hw1p3_questionpic.png">
#
# ## Answer

# %% [markdown]
# The two random variable $X_1$ and $X_2$ have a constant joint pdf.
#
# In order to get the marginal probability, from the graph, we can see that:
#
# $$P(x_1 =0.5) = 2* P( x_1= 0.5) = 2 * P (x = 1.5) $$

# %%
x = [0,0.5,1,1.5,2]
y=[]
for i in range(len(x)):
    if x[i]<=1:
        y.append(x[i])
    else:
        y.append(-1*x[i] +2)

plot(x,y)
ylabel('marginal Probability of X1')
xlabel('X1')

# %%
y
# Out:
# [1, 1, 1, 0, 0]

# %% [markdown]
# The shape of the marginal distribution obtained is a triangle. Since the area under the curve = 1 and x1 varies from 0 to 2 (i.e) width = 2, the height of the triange is 1.

# %% [markdown]
# ### b

# %%
x = [0,0.5,1,1.5,2]
y=[]
for i in range(len(x)):
    if x[i]<=1:
        y.append(1)
    elif x[i]>1:
        y.append(0)
step(x,y)
plt.ylim((0,2))
ylabel('Conditional Probability of X2')
xlabel('X2|X1=0.5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d5d7e731007> in <module>()
#       6     elif x[i]>1:
#       7         y.append(0)
# ----> 8 step(x,y)
#       9 plt.ylim((0,2))
#      10 ylabel('Conditional Probability of X2')
#
# NameError: name 'step' is not defined

# %% [markdown]
# The two random variable $X_1$ and $X_2$ have a constant joint pdf.
# From the graph, we can see that
#
# at $x_1$ = 0.5, the range of $x_2$ is from 0 to 1.
#
# Again, since within the area the distribution is uniform, this means that the probability of $X_2$ will be constant.
#
#
#
# $p_{X_2|X_1}(x_2 \,|\, x_1 = 0.5)$ :
#
# $p_{X_2|X_1}(x_2 \,|\, x_1 = 0.5) = \frac{1}{b-a},$  where $X_2$ lies in the range of a to b.
#
#
# Substituting the value of a =0 and b = 1,
#
# $p_{X_2|X_1}(x_2 \,|\, x_1 = 0.5) = \frac{1}{1-0},$
#
# $p_{X_2|X_1}(x_2 \,|\, x_1 = 0.5) = 1 $

# %% [markdown]
# # Question 4: Bivariate Normal Distribution (20 pts)
#
# Suppose $X$ and $Y$ are two random variables whose joint distribution is Normal (Gaussian), centered at (0,0) and with correlation $\rho$. (See "Bivariate Case" in the Wikipedia entry for "Multivariate Normal Distribution" for the equation, or use just use the vector form given in the class notes, with $\sigma_{12} = \sigma_{21} = \rho \sigma_{x} \sigma_{y} $). Consider 2 cases:
# 1. $\sigma_x^2 = 4; \sigma_y^2 = 16; \rho = 0$
# 2. $\sigma_x^2 = 4; \sigma_y^2 = 16; \rho = 0.5$
#
# a. (8 pts) Obtain contour plots for each of the two distributions using  Python (http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.kdeplot.html).
#
# b. (6 pts) View 3-D plots for the two distributions from at least two different viewing perspectives each (http://matplotlib.org/examples/mplot3d/rotate_axes3d_demo.html).
#
# c.  (6 pts) Consider the bivariate Normal Distribution given in part (ii). We can rotate this distribution by using the rotation matrix
# \begin{equation} \left[ \begin{array}{cc} \cos(\theta) & -\sin(\theta) \\ \sin(\theta) & \cos(\theta) \end{array} \right] \end{equation}
# Check Wikipedia for more info on rotation matrices. This is the same as creating two new random variables:
# \begin{aligned}
# U = X \cos(\theta) - Y \sin(\theta) \\
# V = X \sin(\theta) + Y \cos(\theta)
# \end{aligned}
# For a rotation of -45 degrees, plot the rotated distribution and fit a bivariate gaussian to this rotated distribution.
#
# ## Answer

# %%
import numpy as np; np.random.seed(10)
import seaborn as sns; sns.set(color_codes=True)
# %matplotlib inline

mean, var = [0, 0], [(4, 0), (0, 16)]
x,y = np.random.multivariate_normal(mean, var, size=5000).T

ax = sns.kdeplot(x,y)

# %%
mean, var = [0, 0], [(4, 4), (4, 16)]
x,y = np.random.multivariate_normal(mean, var, size=5000).T
ax = sns.kdeplot(x, y)

# %%
# Part A Angle 1

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
 
delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 2, 4, 0, 0,0)

fig = plt.figure()
ax = fig.gca(projection='3d') 

ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()

# %%
# Part A Angle 2

delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 2, 4, 0, 0,0)

fig = plt.figure()
ax = fig.gca(projection='3d') 

ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

for angle in range(0, 360):
    ax.view_init(210, angle)
    plt.draw()

# %%
#Part B Angle 1

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
 
delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 2, 4, 0, 0,4)

fig = plt.figure()
ax = fig.gca(projection='3d') 
 
ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()

# %%
# Part B Angle 2

delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 2, 4, 0, 0,4)

fig = plt.figure()
ax = fig.gca(projection='3d') 
 
ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)
for angle in range(0, 360):
    ax.view_init(180, angle)
    plt.draw()

# %%
# Part C

angle = np.radians(-45)
cos, sin = np.cos(angle), np.sin(angle)
R = np.matrix([[cos, -sin], [sin, cos]])

mean, cov = [0, 0], [(4, 4), (4, 16)]
dist = np.random.multivariate_normal(mean, cov, size=5000)
dist_matrix = np.asmatrix(dist)

rotate_dist = np.dot(dist_matrix, R).T
u,v = np.array(rotate_dist)

ax = sns.kdeplot(u,v)

# %% [markdown]
# # Question 5: MLR using scikit-learn (20 pts)
#
# Consider the dataset (Advertising.csv), which has the following variables:
#
#   * TV: advertising dollars spent on TV for a single product (in thousands of dollars)
#   * Radio: advertising dollars spent on Radio
#   * Newspaper: advertising dollars spent on Newspaper
#   * Sales (dependent variable): sales of a single product in a given market (in thousands of widgets)
#
#
# We are interested in predicting sales based on the first three "feature" variables (TV, Radio and Newspaper).
#
# 1. (2 pts) Print the shape (number of rows and columns) of the data matrix , and show the first 5 rows. (Use shape and head commands in python)
# 2. (4 pts) Visualize the relationship between the features and the response variable (Sales) using scatterplots. Comment on the fits.
# 2. (2 pts) Fit a simple linear regression of SALES on TV. What is the regression coefficient for TV and what is its interpretation?
# 3. Split the data randomly into a training and test set (keep 1/3rd of the data for test).
#
#   * (4 pts) Fit an MLR on all the feature variables using the training data and evaluate the trained model on the test data using root mean squared error.
#   * (2 pts) Report the MSE obtained on train data. How much does this increase when you score your
# model on test data?
#   * (2 pts) Report the coefficients obtained by your model.
#   * (4 pts) Do you think your MLR model is reasonable for this problem? You may look at the distribution of residuals to provide an informed answer.
#
#
# ## Answer

# %%
from pandas import Series, DataFrame
import pandas as pd

# Read in the data
advertising = pd.read_csv("advertising.csv")

# Print shape and first 5 rows
print "Shape of the matrix: ", advertising.shape,"\n"
print advertising.head(5)
# Out:
# Shape of the matrix:  (200, 5)
#
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
import matplotlib.pyplot as plt
# %pylab inline

# Setting up plotting space
fig,(ax1, ax2, ax3) = subplots(nrows=3,ncols=1,figsize=(8,12))

# TV Vs. Sales
ax1.scatter(advertising["TV"],advertising["Sales"],color='blue')
ax1.set_xlabel('TV')
ax1.set_ylabel('Sales')

# Radio Vs. Sales
ax2.scatter(advertising["Radio"],advertising["Sales"],color='green')
ax2.set_xlabel('Radio')
ax2.set_ylabel('Sales')

# Newspaper Vs. Sales
ax3.scatter(advertising["Newspaper"],advertising["Sales"],color='red')
ax3.set_xlabel('Newspaper')
ax3.set_ylabel('Sales')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### TV Vs. Sales
# There is a strong linear relationship between these two variables (i.e) The sales increase as more is spent on TV promotion.
#
# ### Radio Vs. Sales
# There does seem to be a linear relationship between the two variables but the number of outliers increase as the amount spent on Radio promotion increases.
#
# ### Newspaper Vs. Sales
# There is no relationship between the two variables (i.e) the points are randomly distributed.

# %%
# Linear regression of sales on TV
result = pd.ols(x=advertising["TV"],y=advertising["Sales"])
print result,"\n"
print "The co efficient for TV is: ",result.beta['x']
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         200
# Number of Degrees of Freedom:   2
#
# R-squared:         0.6119
# Adj R-squared:     0.6099
#
# Rmse:              3.2587
#
# F-stat (1, 198):   312.1450, p-value:     0.0000
#
# Degrees of Freedom: model 1, resid 198
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.0475     0.0027      17.67     0.0000     0.0423     0.0528
#      intercept     7.0326     0.4578      15.36     0.0000     6.1352     7.9300
# ---------------------------------End of Summary---------------------------------
#
#
# The co efficient for TV is:  0.047536640433

# %% [markdown]
# The coefficient of TV tells you how much the the dependent variable (sales) is expected to increase when that independent variable (TV) increases by one. The p-value and t-stat show that this result is significant.

# %%
# Splitting data into training and test
from sklearn.cross_validation import train_test_split

X = advertising.drop(['Sales','Unnamed: 0'],axis = 1)
y = advertising["Sales"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

X_train_mod = sm.add_constant(X_train)
X_test_mod = sm.add_constant(X_test)

# %%
# MLR on all features
import statsmodels.api as sm
from patsy import dmatrices
from sklearn.metrics import mean_squared_error
from math import sqrt

# Setting up the model
model = sm.OLS(y_train,X_train_mod)
result_mlr = model.fit()
print result_mlr.summary(),"\n"

# Predicting on test set
pred_test = result_mlr.predict(X_test_mod)
rmse = sqrt(mean_squared_error(y_test, pred_test))
print "RMSE: ",rmse
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     341.6
# Date:                Sun, 11 Sep 2016   Prob (F-statistic):           1.89e-61
# Time:                        10:58:44   Log-Likelihood:                -264.67
# No. Observations:                 134   AIC:                             537.3
# Df Residuals:                     130   BIC:                             548.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          3.0192      0.388      7.775      0.000         2.251     3.787
# ...

# %%
# Predicting on train set
mse_train = mean_squared_error(y_train, result_mlr.fittedvalues)
print "MSE on train: ", mse_train

# Predicting on test set
mse_test = mean_squared_error(y_test, pred_test)
print "MSE on test: ", mse_test,"\n"

print "The increase when scored on test:",mse_test-mse_train
# Out:
# MSE on train:  3.04189016388
# MSE on test:  2.30460308994
#
# The increase when scored on test: -0.737287073944

# %% [markdown]
# The train set actually has a higher error than the test set.

# %%
# Reporting co efficients
print "The co efficients are:","\n",result_mlr.params
# Out:
# The co efficients are:
# const        3.019195
# TV           0.045741
# Radio        0.180924
# Newspaper    0.003142
# dtype: float64

# %%
# Residual distribution

# Setting up plotting space
fig,(ax1, ax2, ax3) = subplots(nrows=3,ncols=1,figsize=(8,12))

# TV Vs. Sales
ax1.scatter(x_train["TV"],result_mlr.fittedvalues-y_train,color='blue')
ax1.set_xlabel('TV')
ax1.set_ylabel('Residuals')

# Radio Vs. Sales
ax2.scatter(x_train["Radio"],result_mlr.fittedvalues-y_train,color='green')
ax2.set_xlabel('Radio')
ax2.set_ylabel('Residuals')

# Newspaper Vs. Sales
ax3.scatter(x_train["Newspaper"],result_mlr.fittedvalues-y_train,color='red')
ax3.set_xlabel('Newspaper')
ax3.set_ylabel('Residuals')

# %% [markdown]
# No, the MLR model obtained is not reasonable for this problem since the error patterns are not random. This means that a non linear model might be a better fit for the data at hand.

# %% [markdown]
# # Question 6: Illustrating the curse of dimensionality (10 pts)
#
# For a hypersphere of radius $a$ in $d$ dimensions, the volume is related to the surface area of a unit hypersphere (S) as
#     $$ V = \frac{S \times a^d}{d}.$$
#
#
# 1. (6 pts) Use this result to show that the fraction of the volume which lies at values of the radius between $a - \epsilon$ and $a$, where $0 < \epsilon < a$, is given by
# $f = 1 - (1 - \epsilon/a)^d$. Hence, show that for any fixed $\epsilon$, no matter how small, this fraction tends to 1 as $d \rightarrow \infty$.
# 2. (4 pts) Evaluate the ratio $f$ numerically, with $\epsilon/a = 0.01$, for the cases $d$ = 2, 10, and 1000.
#
#
# This problem shows that if data are randomly distributed within a very high-dimensional hypersphere, most of the mass is near the surface and there is very little of it near the "core". Thus, there are few "representative" points.

# %% [markdown]
# ## Answer

# %% [markdown]
# #### 1. ####
#
# $V_a = \frac{S \times a^d}{d}$
#
# $V_{a-\epsilon} = \frac{S \times (a-\epsilon)^d}{d}$
#
# $fraction(f) = (V_a - V_{a-\epsilon})/V_a$
#
# $fraction(f) = (\frac{S \times a^d}{d} - \frac{S \times (a-\epsilon)^d}{d})/\frac{S \times a^d}{d} = ( a^d -  (a-\epsilon)^d)/{a^d} = ( 1 -  (\frac{a-\epsilon}{a})^d) = 1 -  (1-{\epsilon}/{a})^d$
#
# As $0 < \epsilon < a$, $\epsilon /a $ is less than 1. Thus, (1- fraction) raised to power infinity will give an infinitely small value that is approximately equal to zero. Hence, f tends to 1 as d tends to infinity.

# %% [markdown]
# #### 2. ####

# %%
a = 0.01
for d in [2,10,1000]:
    print "Ratio f for d="+str(d)+" is "+ str((1-pow((1-a),d)))
# Out:
# Ratio f for d=2 is 0.0199
# Ratio f for d=10 is 0.0956179249912
# Ratio f for d=1000 is 0.999956828753

# %% [markdown]
# This shows that as the dimensions increase, the fraction tends to 1 which means that most of the mass is close to the surface and not the core.
